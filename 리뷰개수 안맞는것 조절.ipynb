# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv('리뷰제목.csv')
df2=pd.read_csv('리뷰내용.csv')

# %%
df1['관광지'].unique()[560:]
# Out:
# array(['송악산', '알뜨르 비행장', '이중섭 미술관', '쇠소깍', '휴애리 자연생활공원', '제주 감귤박물관'],
#       dtype=object)

# %%
x=df1['관광지'].unique()[12]
a=df1[df1['관광지']==x].count()[0]
b=df2[df2['관광지']==x].count()[0]

if a==b:
    print('개수맞음')
else:
    print('개수안맞음')
# Out:
# 개수안맞음

# %%
a,b
# Out:
# (10, 11)

# %% [markdown]
# 서울역사박물관, 창경궁,

# %%
inc=[]
for i in range(566):
    x=df1['관광지'].unique()[i]
    a=df1[df1['관광지']==x].count()[0]
    b=df2[df2['관광지']==x].count()[0]
    
    if a==b:
        pass
    else:
        print('{}번째 : 개수 안맞음.'.format(i+1))
        inc.append(i)
# Out:
# 경복궁
# 삼청동 거리
# 인사동
# 조계사
# 청와대
# 보신각
# 국립민속박물관
# 사직단
# 경교장
# 탑골공원
# 인왕산 선바위와 국사당
# 종묘
# 서울역사박물관
# 창경궁
# 창덕궁
# 북촌한옥마을
# 동대문시장
# 운현궁
# 낙산공원
# 명동성당
# 청계천
# 덕수궁
# 남대문시장
# 서울광장
# 한국은행 화폐금융박물관
# 숭례문
# 농업박물관
# 남산골 한옥마을
# 남산과 N서울타워
# 삼성미술관 리움
# 국립중앙박물관
# 전쟁기념관
# 홍릉수목원
# 아차산북한산국립공원
# 이화벽화마을
# 한강시민공원
# 서울숲
# 세종대왕기념관
# 서울 약령시장
# 길상사
# 북악산 서울 한양도성
# 도봉산
# 독립문
# 서대문형무소
# 절두산 순교성지와 양화진외국인선교사묘원
# 선유도공원
# 여의도공원
# 63스퀘어
# 국립서울현충원
# 관악산
# 헌인릉
# 봉은사
# 롯데월드
# 방이동 백제 고분군
# 몽촌토성
# 올림픽공원
# 동대문디자인플라자
# 국립현대미술관(서울관)
# 아인스월드
# 부천 물박물관
# 부천자연생태박물관과 식물원
# 로보파크
# 유럽자기박물관
# 한국만화박물관
# 원당 허브랜드
# 행주산성
# 서삼릉
# 원당 종마목장
# 일산 호수공원
# 서울대공원
# 국립과천과학관
# 정약용 생가와 묘소
# 수종사
# 동구릉
# 경기도립 물향기수목원
# 철도박물관
# 와우정사
# 세중박물관
# 한택식물원
# 에버랜드
# 삼성화재 교통박물관
# 호암미술관
# 한국민속촌
# 헤이리 문화예술마을
# 임진각 평화누리
# 오두산 통일전망대
# 해강 도자미술관
# 산수유마을
# 칠장사
# 서일농원
# 애기봉전망대
# 죽주산성
# 남사당 전수관
# 덕포진
# 덕포진 교육박물관
# 백남준 아트센터
# 수도국산 달동네박물관
# 제부도
# 송산 공룡알화석지
# 용주사
# 남한산성도립공원
# 장흥아트파크
# 회암사지
# 필룩스조명박물관
# 허브아일랜드
# 국립수목원
# 국망봉 자연휴양림
# 신륵사
# 영녕릉
# 명성황후 생가
# 연천 전곡리 유적
# 아침고요수목원
# ...

# %%
inc
# Out:
# [12, 13, 21, 43, 141, 167, 428]

# %%
x=df1['관광지'].unique()[428]
a=df1[df1['관광지']==x].count()[0]
b=df2[df2['관광지']==x].count()[0]

if a==b:
    print('개수맞음')
else:
    print('개수안맞음')
# Out:
# 개수안맞음

# %%
for i in range(len(inc)):
    a=inc[i]
    print(df1['관광지'].unique()[a])
# Out:
# 서울역사박물관
# 창경궁
# 덕수궁
# 서대문형무소
# 국립춘천박물관
# 속초시립박물관
# 국립진주박물관

# %%
x='국립진주박물관'
a=df1[df1['관광지']==x].count()[0]
b=df2[df2['관광지']==x].count()[0]

print(a,b)
# Out:
# 11 10

# %% [markdown]
# 서울역사박물관 11,10
# 창경궁 10,11
# 덕수궁 11,10
# 서대문형무소 10,11
# 국립춘천박물관 11,10
# 속초시립박물관 10 11
# 국립진주박물관 11 10

# %%
a,b

# %%
df1['관광지'].unique()[0]
# Out:
# '경복궁'

# %%
df2
# Out:
#            관광지                                                 내용
# 0          경복궁  대한민국의 역사가 잠들어 있는 곳. 서울을 방문했다면 꼭 방문해야 되는 곳. 경복궁...
# 1          경복궁  경복궁은 국민들이 자주 찾는곳으로 작성자는 주말에 자주 가족들과 방문하고 있음.특히...
# 2          경복궁  날씨 좋은 날 종종 산책하러 경복궁에 가는데 마음이 편온해지는 기분이라고 할까요? ...
# 3          경복궁  Goooooood 다 좋습니다 다음에 또 오고 싶네요 근처 관광지도많고 먹을거리도많...
# 4          경복궁  요새 더더욱 코로나로 인해 사람 방문이 적음. 두자녀 동반시 성인 입장무료. 지금 ...
# ...        ...                                                ...
# 4696  제주 감귤박물관                                      생각보다 사람이 없네요.
# 4697  제주 감귤박물관            한국 감귤의 역사, 세계 감귤 전시관,열대 식물 온실, 족욕체험도 무료
# 4698  제주 감귤박물관                                 제주도의 역사에대해 나와있습니다.
# 4699  제주 감귤박물관                                              감귤박물관
# 4700  제주 감귤박물관                                          신나는 감귤 축제
#
# [4701 rows x 2 columns]
